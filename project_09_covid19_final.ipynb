# %% [markdown]
# # Covid 19 Dataset

# %% [markdown]
# #### This is the data repository for the 2019 Novel Coronavirus Visual Dashboard operated by the Johns Hopkins University Center for Systems Science and Engineering (JHU CSSE).

# %% [markdown]
# #### Coronavirus is a family of viruses that can cause illness, which can vary from common cold and cough to sometimes more severe disease.The dataset  is provided to identify the deaths and recovered cases.

# %% [markdown]
# Reference links: https://github.com/dsrscientist/COVID_19_Datasets/blob/master/csse_covid_19_daily_reports_us.csv
#
# https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports_us

# %% [markdown]
# #### Field description
# Province_State - The name of the State within the USA.
#
# Country_Region - The name of the Country (US).
#
# Last_Update - The most recent date the file was pushed.
#
# Lat - Latitude.
#
# Long_ - Longitude.
#
# Confirmed - Aggregated confirmed case count for the state.
#
# Deaths - Aggregated Death case count for the state.
#
# Recovered - Aggregated Recovered case count for the state.
#
# Active - Aggregated confirmed cases that have not been resolved (Active = Confirmed - Recovered - Deaths).
#
# FIPS - Federal Information Processing Standards code that uniquely identifies counties within the USA.
#
# Incident_Rate - confirmed cases per 100,000 persons.
#
# People_Tested - Total number of people who have been tested.
#
# People_Hospitalized - Total number of people hospitalized.
#
# Mortality_Rate - Number recorded deaths * 100/ Number confirmed cases.
#
# UID - Unique Identifier for each row entry.
#
# ISO3 - Officialy assigned country code identifiers.
#
# Testing_Rate - Total number of people tested per 100,000 persons.
#
# Hospitalization_Rate - Total number of people hospitalized * 100/ Number of confirmed cases.

# %%
#reading the file
import pandas as pd
df=pd.read_csv("covid19.csv")
df.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-05-21 02:32:54  32.3182  -86.9023
# 1          Alaska             US  2020-05-21 02:32:54  61.3707 -152.4044
# 2  American Samoa             US  2020-05-21 02:32:54 -14.2710 -170.1320
# 3         Arizona             US  2020-05-21 02:32:54  33.7298 -111.4312
# 4        Arkansas             US  2020-05-21 02:32:54  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      13052     522        NaN  12530.0     1     266.194321       164450.0
# 1        401      10      352.0     39.0     2      54.815493        37045.0
# 2          0       0        NaN      0.0    60       0.000000          124.0
# 3      14906     747     3773.0  10386.0     4     204.788838       165435.0
# 4       5003     107     3852.0   1044.0     5     165.782801        96258.0
#
# ...

# %%
#checking the columns in dataset
df.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %%
#dimension of data
df.shape
# Out:
# (58, 18)

# %% [markdown]
# There are 58 rows and 18 columns

# %%
#checking the data type of all columns
df.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %% [markdown]
# There are 4 columns with object datatype they are
# Province_State ,
# Country_Region ,
# Last_Update,
# ISO3
#
# Rest of the columns are either float or int

# %%
#information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %%
#checking for null values
df.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %% [markdown]
# There are null values in the following columns:
#
# Lat
#
# Long_
#
# Recovered_
#
# Incident_Rate
#
# people_tested
#
# people_hostpitalized
#
# Mortality rate
#
# Testing_rate
#
# Hospitalization_rate

# %%
#unique values in each columns
df.nunique()
# Out:
# Province_State          58
# Country_Region           1
# Last_Update              1
# Lat                     56
# Long_                   56
# Confirmed               58
# Deaths                  56
# Recovered               42
# Active                  58
# FIPS                    58
# Incident_Rate           56
# People_Tested           56
# People_Hospitalized     33
# Mortality_Rate          57
# UID                     58
# ISO3                     6
# Testing_Rate            56
# Hospitalization_Rate    33
# dtype: int64

# %% [markdown]
# Dropping columns that are does not affect or don't have severe effect on our target

# %%
#dropping unnecessary columns
df.drop(['Lat', 'Long_','FIPS','UID'],axis=1,inplace=True)
df.sample()
print(df.shape)
# Out:
# (58, 14)

# %% [markdown]
# # Handling NaN values

# %%
#filling the nan values for continuous type of columns
nan_list=['Incident_Rate','Mortality_Rate','Testing_Rate','Hospitalization_Rate']

for i in nan_list:
    df[i]=df[i].fillna(df[i].mean())
    
df.isnull().any() #check if null are filled
# Out:
# Province_State          False
# Country_Region          False
# Last_Update             False
# Confirmed               False
# Deaths                  False
# Recovered                True
# Active                  False
# Incident_Rate           False
# People_Tested            True
# People_Hospitalized      True
# Mortality_Rate          False
# ISO3                    False
# Testing_Rate            False
# Hospitalization_Rate    False
# dtype: bool

# %%
#filling Nan for discrete values
list2=['Recovered','People_Tested','People_Hospitalized']
for j in list2:
    df[j]=df[j].fillna(df[j].median())
    
df.isnull().values.any() #check if null are filled
# Out:
# False

# %% [markdown]
# # Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### univariate analysis

# %%
sns.distplot(df['Confirmed'])
plt.show()

# %% [markdown]
# The data has high right skew of 4.70861433293441
#
# mean=26756.08620689655
#
# median=10148.5

# %%
plt.hist(df["Deaths"])
plt.xlabel("Frequency of Deaths")
plt.show()

# %% [markdown]
# Maximum number of deaths were between 0 to 2500 which occured for nearly 50 times

# %%
plt.hist(df["Recovered"])
plt.xlabel("Count of recovered cases")
plt.show()

# %% [markdown]
# about 0 to 10,000 the data is dense ,the least recovery was at 20,000

# %%
plt.hist(df["Active"])
plt.xlabel("Frequency of Active cases")
plt.show()

# %% [markdown]
# The active cases were dense between 0 to 25000 for nearly 45 times

# %%
plt.hist(df['People_Tested'])
plt.xlabel("People_Tested")
plt.show()

# %%
plt.hist(df['People_Hospitalized'])
plt.xlabel("People_Hospitalized")
plt.show()

# %% [markdown]
# The frequency of people hospitalized were dense at 0 to 50000

# %%
distlist=['Incident_Rate','Mortality_Rate', 'Testing_Rate', 'Hospitalization_Rate']

nrow=2
ncol=2
plt.figure(figsize=(6,6))
for k in distlist:
    plt.subplot(nrow,ncol,distlist.index(k)+1)
    sns.distplot(df[k])
    plt.tight_layout()
    plt.title(k)
plt.show()

# %% [markdown]
# Incident Rate ,Testing Rate has Right skew
#
# Mortality Rate is Normally skewed
#
# Hospitalization Rate resembles to a normal curve with certain peak values

# %% [markdown]
# #### Bivariate Analysis

# %%
sns.scatterplot(x='Testing_Rate',y="People_Tested",palette='tab20',data=df)
plt.show()

# %% [markdown]
# When the testing rate was between 2000 to 4000 most of the people were tested positive

# %%
sns.scatterplot(x='Confirmed',y="Recovered",color='r',data=df)
plt.show()

# %% [markdown]
# For 0 to 50000 the data is dense

# %%
sns.scatterplot(x='Confirmed',y="Deaths",color='b',data=df)
plt.show()

# %% [markdown]
# For confirmed cases between 0 to 50,000 the deaths were below 5000
#
# when confirmed cases were 3,50000 there were 30,000 deaths

# %%
sns.scatterplot(x='People_Hospitalized',y="Deaths",color='b',data=df)
plt.show()

# %% [markdown]
# number of people hospitalized were between 0 to 10,000 and the deaths were between 0 to 5000

# %%
sns.scatterplot(x='People_Hospitalized',y="Recovered",color='g',data=df)
plt.show()

# %% [markdown]
# The density was more between 0 to 10,000

# %%
g = sns.PairGrid(df, vars=["Deaths", "Recovered"], hue="Confirmed")
g.map(sns.scatterplot)
plt.show()

# %%
plt.figure(figsize=(9,25))

ax = sns.barplot(x="Confirmed", y="Province_State",data=df, palette="tab20c",linewidth = 1)

for i,j in enumerate(df["Confirmed"]):
    ax.text(.5, i, j, weight="bold", color = 'black', fontsize =10) #annotations
plt.title("confirmed cases of each state ")

ax.set_xlabel(xlabel = 'Province State', fontsize = 10)
ax.set_ylabel(ylabel = 'Confirmed_cases', fontsize = 10)
plt.show()

# %% [markdown]
# #### Observations

# %% [markdown]
# Maximum cases were reported in NewYork which were 354370 followed by New jersey
#
# The least confirmed cases were found in Northen Marian Island which were 21
#
# 0 cases were reported from American Samoa

# %%
plt.figure(figsize=(9,25))

ax = sns.barplot(x="Deaths", y="Province_State",data=df, palette="Set2",linewidth = 1)

for i,j in enumerate(df["Deaths"]):
    ax.text(.5, i, j, weight="bold", color = 'black', fontsize =10) #annotations
plt.title("Death cases of each state ")

ax.set_xlabel(xlabel = 'Province State', fontsize = 10)
ax.set_ylabel(ylabel = 'Deaths', fontsize = 10)
plt.show()

# %% [markdown]
# Thus the maximum number of deaths occured in New York city
#
# American samoa and diamond princess reported 0 death cases

# %% [markdown]
# #### Box plot

# %%
list1=['Confirmed', 'Deaths', 'Recovered', 'Active',
       'Incident_Rate', 'People_Tested', 'People_Hospitalized',
       'Mortality_Rate', 'Testing_Rate', 'Hospitalization_Rate']
nrow=2
ncol=5
plt.figure(figsize=(10,8))
for r in list1:
    plt.subplot(nrow,ncol,list1.index(r)+1)
    sns.boxplot(df[r],orient='v')
    plt.tight_layout()
    
    
plt.show()

# %% [markdown]
# #### observations

# %% [markdown]
# Hospitalization_rate has no outliers
#
# Rest all the columns have outliers

# %% [markdown]
# # Statistical Analysis

# %%
#checking correlation
df.corr()
# Out:
#                       Confirmed    Deaths  Recovered    Active  Incident_Rate  \
# Confirmed              1.000000  0.982191   0.793441  0.985218       0.708436
# Deaths                 0.982191  1.000000   0.811694  0.954378       0.710105
# Recovered              0.793441  0.811694   1.000000  0.680043       0.534996
# Active                 0.985218  0.954378   0.680043  1.000000       0.700926
# Incident_Rate          0.708436  0.710105   0.534996  0.700926       1.000000
# People_Tested          0.828190  0.742632   0.652961  0.829952       0.441010
# People_Hospitalized    0.858569  0.899983   0.722819  0.827144       0.542577
# Mortality_Rate         0.382537  0.427127   0.316460  0.367626       0.353882
# Testing_Rate           0.332464  0.344465   0.251724  0.321395       0.620621
# Hospitalization_Rate   0.287471  0.298225   0.219257  0.284564       0.196029
#
#                       People_Tested  People_Hospitalized  Mortality_Rate  \
# ...

# %%
#plotting the heatmap of correlation
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,fmt='0.2f',linewidth=3,linecolor='black',cmap= 'gist_stern')
plt.show()

# %% [markdown]
# #### observations

# %% [markdown]
# Our Target ="Deaths"
#
# All the faetures have good positive correlation with target
#
# "confirmed" has the highest/strong psoitive correlation with target=0.98
#
# "Active" has a strong positive correlation of 0.95 with target
#
# "People_Hospitalized" has a strong positive correlation of 0.91 with target
#
# "Hospitalization_rate" has the least correlation of 0.30 with target

# %%
#statistical summary
df.describe()
# Out:
#            Confirmed        Deaths     Recovered         Active  \
# count      58.000000     58.000000     58.000000      58.000000
# mean    26756.086207   1611.017241   5904.137931   20070.724138
# std     52562.031122   4084.750891  10064.152778   41294.705318
# min         0.000000      0.000000     13.000000       0.000000
# 25%      2596.000000     74.000000   1281.750000     812.500000
# 50%     10148.500000    385.000000   3008.000000    5644.500000
# 75%     29395.500000   1394.250000   4383.750000   19291.250000
# max    354370.000000  28636.000000  61886.000000  263848.000000
#
#        Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  \
# count      58.000000   5.800000e+01            58.000000       58.000000
# mean      396.230806   2.228466e+05          3430.017241        4.458248
# std       395.554852   2.939333e+05         10024.887841        2.116191
# min         0.000000   1.240000e+02            65.000000        0.000000
# ...

# %% [markdown]
# The standard deviation for all features is very high except for "Mortality_Rate" and "Hospitalization_Rate"

# %%
plt.figure(figsize=(15,6))
sns.heatmap(df.describe()[1:].transpose(),annot=True,fmt='.2f',linewidth=3,linecolor='black',cmap='nipy_spectral')
plt.show()

# %% [markdown]
# #### Observations

# %% [markdown]
# 1)'Confirmed':
#
#     mean:26756
#
#     median:10148.50
#
#     std:52562.03
#
# 2)'Deaths':
#
#     mean:1611.02
#
#     median:385.00
#
#     std:4084.75
#
# 3):Recovered:
#
#     mean:5904.14
#
#     median:3008
#
#     std:10064.15
#
# 4)'Active':
#
#     mean:20070.72
#
#     median:5644.50
#
#     std:41294.71
#
# 5)'Incident Rate':
#
#     mean:396.23
#
#     median:259.01
#
#     std:395.55
#
# 6)'People_Tested':
#
#     mean:222846.55
#
#     median:138654.50
#
#     std:293933.27
#
# 7)'People_Hospitalized':
#
#     mean:3430.02
#
#     median:138654.50
#
#     std:1493.00
#
# 8)'Mortality Rate':
#
#     mean:4.46
#
#     median:4.41
#
#     std:2.12
#
# 9)'Testing Rate':
#
#     mean:3894.19
#
#     median:3501.53
#
#     std:1898.95
#
# 10)5)'Hopitalization Rate':
#
#     mean:14.34
#
#     median:14.34
#
#     std:3.78

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #### Death cases will ultimately give us "Mortality_Rate" similarly "people_Hospitalized" will give "Hospitalization_rate"
#
# "People_Tested" will yeild us the "tesing_rate"

# %% [markdown]
# #### There out of these 3 columns we shall drop columns which have less correlation with the target variable

# %%
df.drop(['Mortality_Rate','Hospitalization_Rate','Testing_Rate'],axis=1,inplace=True)

# %%
df.sample()
# Out:
#           Province_State Country_Region          Last_Update  Confirmed  \
# 10  District of Columbia             US  2020-05-21 02:32:54       7551
#
#     Deaths  Recovered  Active  Incident_Rate  People_Tested  \
# 10     407     1059.0  6085.0    1069.927127        40419.0
#
#     People_Hospitalized ISO3
# 10               1493.0  USA

# %%
#label encoding for categorical values
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
mylist=['Province_State','Country_Region','Last_Update','ISO3']
for k in mylist:
    df[k]=le.fit_transform(df[k])
    
df.head()
# Out:
#    Province_State  Country_Region  Last_Update  Confirmed  Deaths  Recovered  \
# 0               0               0            0      13052     522     3008.0
# 1               1               0            0        401      10      352.0
# 2               2               0            0          0       0     3008.0
# 3               3               0            0      14906     747     3773.0
# 4               4               0            0       5003     107     3852.0
#
#     Active  Incident_Rate  People_Tested  People_Hospitalized  ISO3
# 0  12530.0     266.194321       164450.0               1493.0     4
# 1     39.0      54.815493        37045.0               1493.0     4
# 2      0.0       0.000000          124.0               1493.0     0
# 3  10386.0     204.788838       165435.0               1792.0     4
# 4   1044.0     165.782801        96258.0                535.0     4

# %%
df.drop(["Country_Region","Last_Update","ISO3"],axis=1,inplace=True)
df.sample()
# Out:
#     Province_State  Confirmed  Deaths  Recovered  Active  Incident_Rate  \
# 10              10       7551     407     1059.0  6085.0    1069.927127
#
#     People_Tested  People_Hospitalized
# 10        40419.0               1493.0

# %%
#checking outliers with the help of zscore
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 5, 34, 36, 36, 36, 36, 36, 36, 36], dtype=int64), array([6, 5, 1, 2, 3, 4, 5, 6, 7], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
print("original shape=",df.shape)
print("new shape=",df_new.shape)
# Out:
# original shape= (58, 8)
# new shape= (55, 8)

# %%
#percentage loss
print("percentage loss due to outliers=",((58-55)/58)*100)
# Out:
# percentage loss due to outliers= 5.172413793103448

# %%
df=df_new #taking the new dataset with no zscores greater than 3

# %%
df.skew()
# Out:
# Province_State         0.013472
# Confirmed              2.005429
# Deaths                 2.213739
# Recovered              2.961192
# Active                 2.586717
# Incident_Rate          1.605849
# People_Tested          1.887213
# People_Hospitalized    2.207066
# dtype: float64

# %% [markdown]
# Except for province state we can see skewness in all columns so we shall treat if afterwards

# %% [markdown]
# # Data split

# %%
#assigning features to x
x=df.drop(["Deaths","Province_State"],axis=1)
x.sample()
# Out:
#     Confirmed  Recovered  Active  Incident_Rate  People_Tested  \
# 51        944      824.0    66.0     151.284718        25058.0
#
#     People_Hospitalized
# 51               1493.0

# %%
#power transformation in order to reduce skewness
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')
x=pd.DataFrame(x)

x.sample()
# Out:
#            0         1         2         3         4         5
# 33 -0.164111 -0.265487  0.012542  0.113245  0.161852 -0.234126

# %%
#checking skewness after being treated
x.skew()
# Out:
# 0   -0.151511
# 1    0.061110
# 2   -0.151134
# 3    0.057380
# 4   -0.052414
# 5    0.032482
# dtype: float64

# %%
#checking if the transormations generated  any NaN values
x.isnull().values.any()
# Out:
# False

# %% [markdown]
# No NaN values are generated

# %%
#standard scaler

from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x=pd.DataFrame(x)
x.head(6)
# Out:
#           0         1         2         3         4         5
# 0  0.280664  0.100793  0.593013 -0.024102  0.296775  0.019327
# 1 -1.286353 -1.339684 -1.462742 -1.370658 -0.829374  0.019327
# 2 -2.183215  0.100793 -1.998654 -2.875240 -2.359594  0.019327
# 3  0.370980  0.289678  0.485826 -0.297714  0.302467  0.197711
# 4 -0.291053  0.307356 -0.564247 -0.501986 -0.171475 -0.877076
# 5  0.680424  0.220887  0.811443  0.436294  0.093651  1.046178

# %%
#assigning Target
y=df["Deaths"]
y.sample()
# Out:
# 16    77
# Name: Deaths, dtype: int64

# %% [markdown]
# # Model Building

# %% [markdown]
# #### finding the best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.linear_model import LinearRegression
lr=LinearRegression()


for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_test=lr.predict(x_test)
    pred_train=lr.predict(x_train)
    
    if round(r2_score(y_train,pred_train)*100,1)<=round(r2_score(y_test,pred_test)*100,1):
        print("At random state i=",i)
        print("for random state",i)
        print("the train accuray is",r2_score(y_train,pred_train)*100)
        print("the testing accuray is",r2_score(y_test,pred_test)*100)
        print("\n")
# Out:
# At random state i= 6
# for random state 6
# the train accuray is 62.61785837823026
# the testing accuray is 71.38618831459071
#
#
# At random state i= 13
# for random state 13
# the train accuray is 62.10792669752118
# the testing accuray is 65.68360298585239
#
#
# At random state i= 17
# for random state 17
# the train accuray is 57.425125703656164
# the testing accuray is 61.11298562041904
#
#
# At random state i= 23
# for random state 23
# the train accuray is 57.50056146342044
# the testing accuray is 59.99784190944987
#
#
# At random state i= 27
# for random state 27
# the train accuray is 62.601533068925065
# the testing accuray is 64.94074355894135
#
#
# At random state i= 34
# for random state 34
# the train accuray is 62.9945876909934
# the testing accuray is 65.41887523188217
#
#
# At random state i= 37
# for random state 37
# the train accuray is 60.26091077188019
# the testing accuray is 74.28891884758961
#
#
# At random state i= 40
# for random state 40
# ...

# %% [markdown]
# #### The best random state is 84

# %%
#splitting the data using best obtained random state
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=84)

# %%
#importing necessary libraries

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

#regularization models
from sklearn.linear_model import Lasso,Ridge,ElasticNet

#bossting/ensemble
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import cross_val_score

# %%
#checking for various algorithms using loop

models=[LinearRegression(),DecisionTreeRegressor(),SVR(),KNeighborsRegressor(),Lasso(),Ridge(),ElasticNet()]

for i in models:
    i.fit(x_train,y_train)
    pred_y=i.predict(x_test)
    print("*)",i,"algorithm")
    print("r2 score is",(r2_score(y_test,pred_y)*100))
    
    cross_score=cross_val_score(i,x,y,cv=3).mean()*100
    print("cross validation score is",cross_score)
    print("mean absolute error=",mean_absolute_error(y_test,pred_y))
    print("mean squared error=",mean_squared_error(y_test,pred_y))
    print("Root mean square error=",np.sqrt(mean_squared_error(y_test,pred_y)))
    print('\n')
# Out:
# *) LinearRegression() algorithm
# r2 score is 63.63036809004403
# cross validation score is -36.430059296107586
# mean absolute error= 671.1991342392038
# mean squared error= 818977.1303744001
# Root mean square error= 904.9735523065854
#
#
# *) DecisionTreeRegressor() algorithm
# r2 score is 89.9259927294085
# cross validation score is 53.890997468871724
# mean absolute error= 307.54545454545456
# mean squared error= 226848.0909090909
# Root mean square error= 476.28572402402625
#
#
# *) SVR() algorithm
# r2 score is -25.45885588204655
# cross validation score is -17.23693853950611
# mean absolute error= 929.8796038964279
# mean squared error= 2825102.382798856
# Root mean square error= 1680.804088166987
#
#
# *) KNeighborsRegressor() algorithm
# r2 score is 68.5573057814616
# cross validation score is 69.40383727641532
# mean absolute error= 408.30909090909086
# mean squared error= 708031.5672727273
# Root mean square error= 841.4461166781431
#
#
# *) Lasso() algorithm
# ...

# %%
#checking model performance for ensemble techniques

ensemble_models=[RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor()]

for m in ensemble_models:
    m.fit(x_train,y_train)
    pred_y=m.predict(x_test)
    print("*",m,"algorithm")
    print("r2 score is",(r2_score(y_test,pred_y)*100))
    cross_score=cross_val_score(m,x,y,cv=3).mean()*100
    print("cross validation score is",cross_score)
    print("mean absolute error=",mean_absolute_error(y_test,pred_y))
    print("mean squared error=",mean_squared_error(y_test,pred_y))
    print("Root mean square error=",np.sqrt(mean_squared_error(y_test,pred_y)))
    print('\n')
# Out:
# * RandomForestRegressor() algorithm
# r2 score is 91.84377451114604
# cross validation score is 70.24381657612989
# mean absolute error= 272.6709090909091
# mean squared error= 183663.17707272724
# Root mean square error= 428.5594207023423
#
#
# * AdaBoostRegressor() algorithm
# r2 score is 91.45773859214685
# cross validation score is 60.52172945757545
# mean absolute error= 281.91223927587566
# mean squared error= 192355.99502442198
# Root mean square error= 438.5840797662656
#
#
# * GradientBoostingRegressor() algorithm
# r2 score is 92.77544115743841
# cross validation score is 60.15065085678445
# mean absolute error= 251.10918118195985
# mean squared error= 162683.7600047972
# Root mean square error= 403.3407492490651

# %% [markdown]
# #### The best among all the above are gradient Boosting and random Forests so we shall hypertune them and check for their performance

# %% [markdown]
# # Gradient Boosting Regressor

# %%
#hypertuning Gradient Boosting
from sklearn.model_selection import GridSearchCV 
gb=GradientBoostingRegressor()

parameters={'loss':['ls','lad','huber','quantile'],'learning_rate':[0.1,0.2,0.3,0.4],
            'n_estimators':[50,30,100,200],'criterion':['mse','mae','friedman_mse']}
pqr=GridSearchCV(gb,parameters)
pqr.fit(x_train,y_train)
print(pqr.best_params_)
# Out:
# {'criterion': 'mse', 'learning_rate': 0.3, 'loss': 'huber', 'n_estimators': 200}

# %%
#using the best parameter obtained above
gb=GradientBoostingRegressor(loss='huber',n_estimators=200,criterion='mse',learning_rate=0.3)
gb.fit(x_train,y_train)
y_pred=gb.predict(x_test)
pred_train=gb.predict(x_train) 
gb_score=r2_score(y_test,y_pred)*100
print("r2 score for test =",gb_score)
print("train score=",r2_score(y_train,pred_train)*100) #ttrain score
gb_crossval=cross_val_score(gb,x,y,cv=3).mean()*100
print("cross_validation score=",gb_crossval)
print("mean absolute error=",mean_absolute_error(y_test,pred_y))
print("mean squared error=",mean_squared_error(y_test,pred_y))
print("Root mean square error=",np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score for test = 86.85461514412123
# train score= 99.9999994975345
# cross_validation score= 66.80547408735497
# mean absolute error= 251.10918118195985
# mean squared error= 162683.7600047972
# Root mean square error= 403.3407492490651

# %% [markdown]
# # RandomForest

# %%
#hypertuning Random Forest Regressor
from sklearn.model_selection import GridSearchCV
Rf=RandomForestRegressor()

parameters={"criterion":["mse","mae"],"max_features":['auto','sqrt','log2'],"n_estimators":[10,20,30,40,50],
           'random_state':range(0,50)}
pqr=GridSearchCV(Rf,parameters)
pqr.fit(x_train,y_train)
print(pqr.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'sqrt', 'n_estimators': 10, 'random_state': 45}

# %%
#using the best parameter obtained above
Rf=RandomForestRegressor(criterion='mae',n_estimators=10,max_features='sqrt',random_state=45)
Rf.fit(x_train,y_train)
y_pred=Rf.predict(x_test)
pred_train=Rf.predict(x_train) 
Rf_score=r2_score(y_test,y_pred)*100

print("r2 score for test=",Rf_score)
print("train score=",r2_score(y_train,pred_train)*100) #ttrain score
Rf_crossval=cross_val_score(Rf,x,y,cv=3).mean()*100
print("cross_validation score=",Rf_crossval)
print('\n')
print("mean absolute error=",mean_absolute_error(y_test,pred_y))
print("mean squared error=",mean_squared_error(y_test,pred_y))
print("Root mean square error=",np.sqrt(mean_squared_error(y_test,pred_y)))
# Out:
# r2 score for test= 86.70434625475956
# train score= 95.42875623456604
# cross_validation score= 70.28357340201738
#
#
# mean absolute error= 251.10918118195985
# mean squared error= 162683.7600047972
# Root mean square error= 403.3407492490651

# %% [markdown]
# # Best Fit Line

# %%
plt.figure(figsize=(4,2))
plt.scatter(x=y_test,y=y_pred,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel("Actual values",fontsize=14)
plt.ylabel('predicted value',fontsize=14)
plt.title("Best Fit Line for RandomForest regressor")
plt.show()

# %% [markdown]
# # Saving the best model

# %%
import pickle
filename="covid19.pkl"
pickle.dump(Rf,open(filename,'wb'))

# %%
actual=np.array(y_test)

# %%
predicted=np.array(y_pred)

# %%
df_com=pd.DataFrame({"actual values":actual,"predicted values":predicted})
df_com
# Out:
#     actual values  predicted values
# 0              69             116.7
# 1             202             380.7
# 2              46             168.0
# 3            3529            2187.4
# 4             138             403.3
# 5             310             888.8
# 6             640             578.1
# 7             407             225.1
# 8            4770            3781.1
# 9            1299            1184.7
# 10            726             831.1

# %% [markdown]
# # Conclusion

# %% [markdown]
# I have trained and tested my model using RandomForest Regressor.
#
# Various evaluation/performance metrics have been observed.
#
# As the data is real time we get accuracy(r2 score)=95
#
# RMSE=403
#
# The best fit line is plotted.
